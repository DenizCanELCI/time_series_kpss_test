# %%
# Burada KPSS testi incelenmiştir
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import kpss

# %%
#Sıcaklık değerlerini csv olarak import ediyoruz
path = 'https://raw.githubusercontent.com/selva86/datasets/master/daily-min-temperatures.csv'
df = pd.read_csv(path, parse_dates=['Date'], index_col='Date')
df.plot(title='Daily Temperatures', figsize=(14,8), legend=None);

# %%
# Burada kpss testi için fonksiyon oluşturuyoruz
def kpss_test(series, **kw):    
    statistic, p_value, n_lags, critical_values = kpss(series, **kw)
    print(f'KPSS Statistic: {statistic}')
    # p değerimiz
    print(f'p-value: {p_value}')
    # lag sayısı
    print(f'num lags: {n_lags}')
    print('Critial Values:')
    for key, value in critical_values.items():
        print(f'   {key} : {value}')
    print(f'Result: The series is {"not " if p_value < 0.05 else ""}stationary')

# %%
# kpss testindek anahtar noktamız p-value(p değeri).
# Eğer KPSS testi sonucu hesaplanan p değeri 0.05'den büyük ise 
# serimiz durağan(stationary), aksi takdirde durağan değildir(non-stationary).
kpss_test(df)
# Out:
# KPSS Statistic: 0.05570612670427435
# p-value: 0.1
# num lags: 36
# Critial Values:
#    10% : 0.347
#    5% : 0.463
#    2.5% : 0.574
#    1% : 0.739
# Result: The series is stationary
# C:\Users\hhhjk\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:2022: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(

# %%
# Bu örnekte serimiz durağan bir zaman serisidir.
